# %% [markdown]
# # import libraries and data set

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/alisoncoolidge/Desktop/Happiness Project'

# %%
df = pd.read_csv(os.path.join(path, 'Datasets', 'UN Happiness Data.csv'))

# %%
# checking import
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.302574        0.450662
# 1     Afghanistan  2009     4.401778            7.472446        0.552308
# 2     Afghanistan  2010     4.758381            7.579183        0.539075
# 3     Afghanistan  2011     3.831719            7.552006        0.521104
# 4     Afghanistan  2012     3.782938            7.637953        0.520637
# ...           ...   ...          ...                 ...             ...
# 2084     Zimbabwe  2017     3.638300            8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480            8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523            8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802            8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578            8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2089.000000  2089.000000         2062.000000     2076.000000
# mean   2013.727621     5.473747            9.378408        0.811542
# std       4.455614     1.115567            1.143520        0.118935
# min    2005.000000     2.178809            5.526723        0.290184
# 25%    2010.000000     4.651972            8.473547        0.747664
# 50%    2014.000000     5.405246            9.463269        0.834770
# 75%    2017.000000     6.294282           10.347656        0.904682
# max    2021.000000     8.018934           11.665803        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2031.000000                   2057.000000
# mean                          63.180326                      0.745462
# std                            6.948546                      0.140751
# min                            6.720000                      0.257534
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country name                       2089 non-null   object
#  1   year                               2089 non-null   int64
#  2   Life Ladder                        2089 non-null   float64
#  3   Log GDP per capita                 2062 non-null   float64
#  4   Social support                     2076 non-null   float64
#  5   Healthy life expectancy at birth   2031 non-null   float64
#  6   Freedom to make life choices       2057 non-null   float64
#  7   Generosity                         2009 non-null   float64
#  8   Perceptions of corruption          1976 non-null   float64
#  9   Positive affect                    2065 non-null   float64
#  10  Negative affect                    2073 non-null   float64
# ...

# %%
df.shape
# Out:
# (2089, 12)

# %% [markdown]
# # CLEANING, WRANGLING, CONSISTENCY
#
# Change column names for clarity
# Check/ change data types
# Check for mixed data
# Drop unnecessary columns
# Check for missing values
# Check for duplicates

# %%
# Change column names for clarity -- Log GDP per capita to just GDP per capita

df.rename(columns = {'Log GDP per capita' : 'GDP per capita'}, inplace = True)

# %%
# Check for rename

df.head(1)
# Out:
#   Country name  year  Life Ladder  GDP per capita  Social support  \
# 0  Afghanistan  2008      3.72359        7.302574        0.450662
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                      0.718114    0.173169
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.414297         0.258195
#
#    Confidence in national government
# 0                           0.612072

# %%
# Check data types -- change year to object

df['year'] = df['year'].astype('object')

# %%
# checking data type change

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country name                       2089 non-null   object
#  1   year                               2089 non-null   object
#  2   Life Ladder                        2089 non-null   float64
#  3   GDP per capita                     2062 non-null   float64
#  4   Social support                     2076 non-null   float64
#  5   Healthy life expectancy at birth   2031 non-null   float64
#  6   Freedom to make life choices       2057 non-null   float64
#  7   Generosity                         2009 non-null   float64
#  8   Perceptions of corruption          1976 non-null   float64
#  9   Positive affect                    2065 non-null   float64
#  10  Negative affect                    2073 non-null   float64
# ...

# %%
# Check for mixed type data

for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
# no mixed type data to address
# no columns need to be dropped, all relevant to analysis

# %%
# creating a subset of the  dataframe to view all the missing values:

df_nan = df[df['GDP per capita'].isnull() == True]

# %%
df_nan
# Out:
#                    Country name  year  Life Ladder  GDP per capita  \
# 12                  Afghanistan  2021     2.436034             NaN
# 449                        Cuba  2006     5.417869             NaN
# 463                      Cyprus  2021     6.269202             NaN
# 758   Hong Kong S.A.R. of China  2021     5.321551             NaN
# 971                      Kosovo  2007     5.103906             NaN
# 985                      Kosovo  2021     6.648499             NaN
# 1165                      Malta  2021     6.443715             NaN
# 1373               North Cyprus  2012     5.463305             NaN
# 1374               North Cyprus  2013     5.566803             NaN
# 1375               North Cyprus  2014     5.785979             NaN
# 1376               North Cyprus  2015     5.842550             NaN
# 1377               North Cyprus  2016     5.827128             NaN
# 1378               North Cyprus  2018     5.608056             NaN
# ...

# %%
df_nan2 = df[df['Social support'].isnull() == True]

# %%
df_nan2
# Out:
#               Country name  year  Life Ladder  GDP per capita  Social support  \
# 27                 Algeria  2010     5.463567        9.302982             NaN
# 120                Bahrain  2014     6.165134       10.783138             NaN
# 311                 Canada  2007     7.481753       10.733970             NaN
# 495               Djibouti  2010     5.005811        7.934187             NaN
# 992                 Kuwait  2014     6.180139       10.944602             NaN
# 1246               Morocco  2010     4.383247        8.745358             NaN
# 1405                  Oman  2011     6.852982       10.392095             NaN
# 1528                 Qatar  2010     6.849653       11.471148             NaN
# 1531                 Qatar  2015     6.374529       11.471742             NaN
# 1866               Tunisia  2009     5.025470        9.262184             NaN
# 1943  United Arab Emirates  2014     6.539855       11.042156             NaN
# ...

# %%
df_nan3 = df[df['Healthy life expectancy at birth'].isnull() == True]

# %%
df_nan3
# Out:
#                    Country name  year  Life Ladder  GDP per capita  \
# 747   Hong Kong S.A.R. of China  2006     5.511187       10.746424
# 748   Hong Kong S.A.R. of China  2008     5.137262       10.815546
# 749   Hong Kong S.A.R. of China  2009     5.397056       10.788493
# 750   Hong Kong S.A.R. of China  2010     5.642835       10.846634
# 751   Hong Kong S.A.R. of China  2011     5.474011       10.886932
# 752   Hong Kong S.A.R. of China  2012     5.483765       10.892753
# 753   Hong Kong S.A.R. of China  2014     5.458051       10.939503
# 754   Hong Kong S.A.R. of China  2016     5.498421       10.969857
# 755   Hong Kong S.A.R. of China  2017     5.362475       10.999584
# 756   Hong Kong S.A.R. of China  2019     5.659317       10.995179
# 757   Hong Kong S.A.R. of China  2020     5.295341       10.935853
# 758   Hong Kong S.A.R. of China  2021     5.321551             NaN
# 971                      Kosovo  2007     5.103906             NaN
# ...

# %%
df_nan4 = df[df['Freedom to make life choices'].isnull() == True]

# %%
df_nan4
# Out:
#               Country name  year  Life Ladder  GDP per capita  Social support  \
# 30                 Algeria  2014     6.354898        9.351205        0.818189
# 31                 Algeria  2016     5.340854        9.378069        0.748588
# 120                Bahrain  2014     6.165134       10.783138             NaN
# 278               Cambodia  2006     3.568745        7.746449        0.793081
# 361                  China  2006     4.560495        8.696139        0.747011
# 362                  China  2007     4.862862        8.823968        0.810852
# 369                  China  2014     5.195619        9.380201        0.820366
# 370                  China  2015     5.303878        9.442431        0.793734
# 371                  China  2016     5.324956        9.502946        0.741703
# 531                  Egypt  2008     4.631741        9.186407        0.738364
# 834                   Iraq  2013     4.725017        9.227219        0.728285
# ...

# %%
df_nan5 = df[df['Generosity'].isnull() == True]

# %%
df_nan5
# Out:
#        Country name  year  Life Ladder  GDP per capita  Social support  \
# 12      Afghanistan  2021     2.436034             NaN        0.454175
# 30          Algeria  2014     6.354898        9.351205        0.818189
# 31          Algeria  2016     5.340854        9.378069        0.748588
# 72        Australia  2005     7.340688       10.650703        0.967892
# 118         Bahrain  2012     5.027187       10.715217        0.911350
# ...             ...   ...          ...             ...             ...
# 1967  United States  2006     7.181794       10.921763        0.964572
# 2014      Venezuela  2005     7.169621        9.316229        0.955278
# 2028      Venezuela  2020     4.573830             NaN        0.805224
# 2029      Venezuela  2021     5.107553             NaN        0.812418
# 2041        Vietnam  2017     5.175279        8.875628             NaN
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df_nan6 = df[df['Perceptions of corruption'].isnull() == True]

# %%
df_nan6
# Out:
#      Country name  year  Life Ladder  GDP per capita  Social support  \
# 30        Algeria  2014     6.354898        9.351205        0.818189
# 31        Algeria  2016     5.340854        9.378069        0.748588
# 120       Bahrain  2014     6.165134       10.783138             NaN
# 121       Bahrain  2015     6.007375       10.781260        0.852551
# 122       Bahrain  2016     6.169673       10.777658        0.862700
# ...           ...   ...          ...             ...             ...
# 2039      Vietnam  2015     5.076315        8.770014        0.848677
# 2041      Vietnam  2017     5.175279        8.875628             NaN
# 2046        Yemen  2007     4.477133        8.211859        0.824969
# 2054        Yemen  2016     3.825631        7.552322        0.775407
# 2055        Yemen  2017     3.253560        7.243477        0.789555
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df_nan7 = df[df['Positive affect'].isnull() == True]

# %%
df_nan7
# Out:
#               Country name  year  Life Ladder  GDP per capita  Social support  \
# 27                 Algeria  2010     5.463567        9.302982             NaN
# 120                Bahrain  2014     6.165134       10.783138             NaN
# 134             Bangladesh  2014     4.635565        8.163840        0.577065
# 143                Belarus  2008     5.463332        9.676768        0.903700
# 278               Cambodia  2006     3.568745        7.746449        0.793081
# 279               Cambodia  2007     4.155971        7.828795        0.675132
# 495               Djibouti  2010     5.005811        7.934187             NaN
# 834                   Iraq  2013     4.725017        9.227219        0.728285
# 924                 Jordan  2007     5.598057        9.341366        0.840607
# 935                 Jordan  2018     4.638934        9.211679        0.799544
# 936                 Jordan  2019     4.452548        9.217453        0.792560
# ...

# %%
df_nan8 = df[df['Negative affect'].isnull() == True]

# %%
df_nan8
# Out:
#               Country name  year  Life Ladder  GDP per capita  Social support  \
# 27                 Algeria  2010     5.463567        9.302982             NaN
# 120                Bahrain  2014     6.165134       10.783138             NaN
# 495               Djibouti  2010     5.005811        7.934187             NaN
# 935                 Jordan  2018     4.638934        9.211679        0.799544
# 936                 Jordan  2019     4.452548        9.217453        0.792560
# 937                 Jordan  2020     4.093992        9.191826        0.708840
# 992                 Kuwait  2014     6.180139       10.944602             NaN
# 1137              Maldives  2018     5.197575        9.841285        0.913315
# 1246               Morocco  2010     4.383247        8.745358             NaN
# 1482           Philippines  2006     4.669946        8.561845        0.795313
# 1528                 Qatar  2010     6.849653       11.471148             NaN
# ...

# %%
df_nan9 = df[df['Confidence in national government'].isnull() == True]

# %%
df_nan9
# Out:
#      Country name  year  Life Ladder  GDP per capita  Social support  \
# 14        Albania  2009     5.485470        9.241250        0.833047
# 15        Albania  2010     5.268937        9.282614        0.733152
# 16        Albania  2011     5.867422        9.310439        0.759434
# 27        Algeria  2010     5.463567        9.302982             NaN
# 28        Algeria  2011     5.317194        9.312737        0.810234
# ...           ...   ...          ...             ...             ...
# 2042      Vietnam  2018     5.295547        8.934052        0.831945
# 2043      Vietnam  2019     5.467451        8.992331        0.847592
# 2044      Vietnam  2020     5.462342        9.011930        0.764510
# 2045      Vietnam  2021     5.540250        9.028702        0.799494
# 2057        Yemen  2019     4.196913        7.447973        0.870043
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
# note on NaNs: since they vary year to year and country to country, NaN's will be left as is, so as not to impact the statistical analysis.

# %%
# check for duplicates

df_dupes = df[df.duplicated()]

# %%
df_dupes
# Out:
# Empty DataFrame
# Columns: [Country name, year, Life Ladder, GDP per capita, Social support, Healthy life expectancy at birth, Freedom to make life choices, Generosity, Perceptions of corruption, Positive affect, Negative affect, Confidence in national government]
# Index: []

# %%
# no duplicates to address

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Country name  year  Life Ladder  GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590        7.302574        0.450662
# 1     Afghanistan  2009     4.401778        7.472446        0.552308
# 2     Afghanistan  2010     4.758381        7.579183        0.539075
# 3     Afghanistan  2011     3.831719        7.552006        0.521104
# 4     Afghanistan  2012     3.782938        7.637953        0.520637
# ...           ...   ...          ...             ...             ...
# 2084     Zimbabwe  2017     3.638300        8.241609        0.754147
# 2085     Zimbabwe  2018     3.616480        8.274620        0.775388
# 2086     Zimbabwe  2019     2.693523        8.196998        0.759162
# 2087     Zimbabwe  2020     3.159802        8.117733        0.717243
# 2088     Zimbabwe  2021     3.154578        8.153248        0.685151
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# # statistical analysis

# %%
df.describe()
# Out:
#        Life Ladder  GDP per capita  Social support  \
# count  2089.000000     2062.000000     2076.000000
# mean      5.473747        9.378408        0.811542
# std       1.115567        1.143520        0.118935
# min       2.178809        5.526723        0.290184
# 25%       4.651972        8.473547        0.747664
# 50%       5.405246        9.463269        0.834770
# 75%       6.294282       10.347656        0.904682
# max       8.018934       11.665803        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2031.000000                   2057.000000
# mean                          63.180326                      0.745462
# std                            6.948546                      0.140751
# min                            6.720000                      0.257534
# 25%                           58.965000                      0.651689
# 50%                           64.980003                      0.767357
# ...

# %%
# export dataframe

df.to_csv(os.path.join(path,'Datasets', 'happiness_data_clean.csv'))
